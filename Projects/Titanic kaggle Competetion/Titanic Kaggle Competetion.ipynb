# %%
import pandas as pd
import numpy as np
train=pd.read_csv('train.csv')
# train.head()
# np.round(100*train.isnull().sum()/len(train),2)
# train=train.drop(['Cabin','PassengerId'],axis=1)
# train=train.dropna()
mean_age=np.mean(train['Age'].dropna())
for i in train.index:
    if train['Age'].isnull()[i]==True:
        train['Age'][i]=mean_age
# np.round(100*train.isnull().sum()/len(train),2)
# train.describe(include='all')
# y=train['Survived']
# x1=train.drop(['Survived','Name','Ticket','Parch','Fare','Embarked','Age'],axis=1)
# x1=train.drop(['Survived'],axis=1)
# x1['Sex']=x1['Sex'].map({'male':0,'female':1})
# x1
# Out:
# C:\Users\devgu\AppData\Local\Temp\ipykernel_13384\4260668912.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Age'][i]=mean_age

# %%
# import statsmodels.api as sm
# x=sm.add_constant(x1)
# reg=sm.Logit(y,x)
# results=reg.fit()
# results.summary()

# %%
# test=pd.read_csv('test.csv')
# test.head()
# test1=test.drop(['PassengerId','Name','Ticket','Parch','Fare','Embarked','Cabin','Age'],axis=1)
# test1['Sex']=test1['Sex'].map({'male':0,'female':1})
# test1
# mean_age1=np.mean(test1['Age'].dropna())
# for i in test1.index:
#     if test1['Age'].isnull()[i]==True:
#         test1['Age'][i]=mean_age1
# test1
# test2=sm.add_constant(test1)
# y_hat=results.predict(test2)
# y_hat=list(y_hat)
# y_hat
# for i in range(len(y_hat)):
#     if y_hat[i]<0.5:
#         y_hat[i]=0
#     else:
#         y_hat[i]=1
# y_hat=pd.Series(y_hat)
# y_hat
# df=pd.DataFrame(zip(test['PassengerId'],y_hat),columns=['PassengerId','Survived'])
# df
# df.to_csv('predicted.csv', index=False)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
y=train['Survived']

# %%
# for i in y.index:
#     if y[i]<=0.5:
#         y[i]=0
#     else:
#         y[i]=1
# Out:
# C:\Users\devgu\AppData\Local\Temp\ipykernel_13384\474814398.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i]=0
# C:\Users\devgu\AppData\Local\Temp\ipykernel_13384\474814398.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i]=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.subplot(1,2,1)
plt.title('Survived Histogram')
y.hist()
plt.subplot(1,2,2)
train['Pclass'].hist()
plt.title('Pclass Histogram')
# Out:
# Text(0.5, 1.0, 'Pclass Histogram')

# %%
plt.subplot(1,2,1)
train['Sex'].hist()
plt.title('Sex Histogram')
plt.subplot(1,2,2)
train['Age'].hist()
plt.title('Age Histogram')
# Out:
# Text(0.5, 1.0, 'Age Histogram')

# %%
plt.subplot(1,2,1)
train['SibSp'].hist()
plt.title('SibSp Histogram')
plt.subplot(1,2,2)
train['Parch'].hist()
plt.title('Parch Histogram')
# Out:
# Text(0.5, 1.0, 'Parch Histogram')

# %%
train['Ticket'].hist()
plt.title('Ticket Histogram')
# Out:
# Text(0.5, 1.0, 'Ticket Histogram')

# %%
train['Fare'].hist()
plt.title('Fare Histogram')
# Out:
# Text(0.5, 1.0, 'Fare Histogram')

# %%
plt.subplot(1,2,1)
train['Cabin'].hist()
plt.title('Cabin Histogram')
plt.subplot(1,2,2)
train['Embarked'].hist()
plt.title('Embarked Histogram')
# Out:
# Text(0.5, 1.0, 'Embarked Histogram')

# %%
sns.boxplot(train['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
corr=train.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="white")
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(15, 10))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, annot_kws={"fontsize":8})
# Out:
# <AxesSubplot:>
